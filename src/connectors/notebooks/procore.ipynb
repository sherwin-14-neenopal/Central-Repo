# %%
import os
import json
import httpx
import ProPyCore 
import pandas as pd


from typing import Optional
from typing import Dict, Any
from dotenv import load_dotenv
from ProPyCore.procore import Procore

# %%
load_dotenv(os.path.join("..", "..", "config", ".env"))

CLIENT_ID = os.getenv("CLIENT_ID_PROCORE")
CLIENT_SECRET = os.getenv("CLIENT_SECRET_PROCORE")
REDIRECT_URI = os.getenv('REDIRECT_URI_PROCORE')
ACCESS_TOKEN = os.getenv('ACCESS_TOKEN_PROCORE')
OAUTH_URL = os.getenv('OAUTH_URL_PROCORE')
BASE_URL = os.getenv('BASE_URL_PROCORE')

conn = Procore(
        client_id = CLIENT_ID,
        client_secret = CLIENT_SECRET,
        redirect_uri = REDIRECT_URI, 
        oauth_url = OAUTH_URL,
        base_url = BASE_URL
)

companies = conn.companies.get()
for company in companies:
    print(f"Project: {company['name']} ({company['id']})")
# Out:
# ---------------------------------------------------------------------------
# NoPrivilegeError                          Traceback (most recent call last)
# Cell In[6], line 18
#       8 BASE_URL = os.getenv('BASE_URL_PROCORE')
#      10 conn = Procore(
#      11         client_id = CLIENT_ID,
#      12         client_secret = CLIENT_SECRET,
#    (...)     15         base_url = BASE_URL
#      16 )
# ---> 18 companies = conn.companies.get()
#      19 for company in companies:
#      20     print(f"Project: {company['name']} ({company['id']})")
#
# File c:\Users\SherwinVarghese\AppData\Local\pypoetry\Cache\virtualenvs\central-repo-C1khgJZ_-py3.13\Lib\site-packages\ProPyCore\access\companies.py:34, in Companies.get(self, page, per_page)
#      15 """
#      16 Gets all companies where the data connection app is installed
#      17
#    (...)     26     list where each value is a dict with the company's id, active status (is_active), and name
#      27 """
#      28 params = {
#      29     "page": page,
#      30     "per_page": per_page,
#      31     "include_free_companies": True
#      32 }
# ---> 34 companies = self.get_request(
#      35     api_url=self.endpoint,
#      36     params=params
#      37 )
#      39 return companies
#
# File c:\Users\SherwinVarghese\AppData\Local\pypoetry\Cache\virtualenvs\central-repo-C1khgJZ_-py3.13\Lib\site-packages\ProPyCore\access\base.py:63, in Base.get_request(self, api_url, additional_headers, params)
#      61     return response.json()
#      62 else:
# ---> 63     raise_exception(response)
#
# File c:\Users\SherwinVarghese\AppData\Local\pypoetry\Cache\virtualenvs\central-repo-C1khgJZ_-py3.13\Lib\site-packages\ProPyCore\exceptions.py:74, in raise_exception(response)
#      71     raise UnauthorizedClientError('401: Wrong client secret or/and refresh token', response.text)
#      73 elif response.status_code == 403:
# ---> 74     raise NoPrivilegeError(f"403: Data connection app or permission template does not have access to this endpoint", response.text)
#      76 elif response.status_code == 404:
#      77     raise NotFoundClientError('404: Client ID doesn\'t exist', response.text)
#
# NoPrivilegeError: '403: Data connection app or permission template does not have access to this endpoint'

# %%
url = "https://api.procore.com/rest/v1.0/me"
params = {
    "company_id": "SOME_INTEGER_VALUE",
    "project_id": "SOME_INTEGER_VALUE"
}

response = httpx.get(url, params=params)

print(response.text)
# Out:
# {"error":"Invalid Token"}
