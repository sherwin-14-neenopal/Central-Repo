# %%
import os
import json
import httpx
import ProPyCore
import pandas as pd


from typing import Optional
from typing import Dict, Any
from dotenv import load_dotenv
from ProPyCore.procore import Procore

# %%
load_dotenv(os.path.join("..", "..", "config", ".env"))

CLIENT_ID = os.getenv("CLIENT_ID_PROCORE")
CLIENT_SECRET = os.getenv("CLIENT_SECRET_PROCORE")
OAUTH_URL = os.getenv('OAUTH_URL_PROCORE')
BASE_URL = os.getenv('BASE_URL_PROCORE')


try:
    conn = Procore(
        client_id = CLIENT_ID,
        client_secret = CLIENT_SECRET,
        redirect_uri = "urn:ietf:wg:oauth:2.0:oob", 
        oauth_url = OAUTH_URL,
        base_url = BASE_URL
    )

except Exception as e:
    print(f"An error occurred: {e}")
    print(f"Error type: {type(e)}")
    print(f"Error message: {str(e)}")
# Out:
# An error occurred: 'access_token'
# Error type: <class 'KeyError'>
# Error message: 'access_token'

# %%
try:
    response = httpx.post(
        OAUTH_URL + "/oauth/token",
        headers={"Content-Type": "application/x-www-form-urlencoded"},
        data={
            "grant_type": "client_credentials",
            "client_id": CLIENT_ID,
            "client_secret": CLIENT_SECRET,
        },
    )

    response.raise_for_status()

    access_token_response = response.json()

    print(access_token_response)

    access_token = access_token_response["access_token"]

except requests.exceptions.RequestException as e:
    print(f"Request error: {e}")
except KeyError as e:
    print(f"Key error: {e}")
    print(f"Error message: {str(e)}")
except Exception as e:
    print(f"An error occurred: {e}")
    print(f"Error type: {type(e)}")
    print(f"Error message: {str(e)}")
# Out:
# {'access_token': 'eyJhbGciOiJFUzUxMiJ9..ABjI9AZPQYB2R1fPorztSNJqmJg-rIw5G8VelUk-53rM9TzLF7WK0krqA-Ld9Q6s17C0imu4St9JwldNkGnZ5fUrAPsg4USSIZeW84KXBB-3o8nZw3Tp-S6SFm9D-827Ce7fJg0eRz7dO8V5Bot_53u43jhEx3iMWnovywCXUO1mWybJ', 'token_type': 'Bearer', 'expires_in': 5400, 'scope': 'procore_all', 'created_at': 1742191899}
