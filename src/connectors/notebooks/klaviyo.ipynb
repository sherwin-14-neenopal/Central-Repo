# %%
import os
import json
import pandas as pd


from typing import Optional
from typing import Dict, Any
from dotenv import load_dotenv
from klaviyo_api import KlaviyoAPI

# %%
# Loading api token from config dir
load_dotenv(os.path.join("..", "..", "config", ".env"))
API_KEY_KLAVIYO = os.environ.get("API_KEY_KLAVIYO")

klaviyo = KlaviyoAPI(API_KEY_KLAVIYO, max_delay = 60, max_retries = 3, test_host = None)

# %%
## The function show_json would help prettifying JSON outputs

def show_json(variable: Dict[str, Any]) -> None:
    print(json.dumps(variable, indent = 2))

# %% [markdown]
# ### Accounts

# %%
try:
    accounts = klaviyo.Accounts.get_accounts(
        fields_account = ['industry','timezone']
    )
    show_json(accounts)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "account",
#       "id": "UUM8uE",
#       "attributes": {
#         "industry": null,
#         "timezone": "US/Eastern"
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/accounts/UUM8uE/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/accounts?fields%5Baccount%5D=industry,timezone",
#     "next": null,
#     "prev": null
#   }
# }

# %% [markdown]
# ### Profiles

# %%
try:
    profiles = klaviyo.Profiles.get_profiles(
                additional_fields_profile =  ['predictive_analytics'], 
                fields_profile =  ['first_name', 'location'],
                filter = None, 
                page_cursor = None,
                page_size = 20, 
                sort = 'created'
    )
    show_json(profiles)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "profile",
#       "id": "01JNT4KAWQX1G11QYMR5Y17A5M",
#       "attributes": {
#         "first_name": null,
#         "location": {
#           "longitude": null,
#           "city": null,
#           "country": null,
#           "region": null,
#           "latitude": null,
#           "zip": null,
#           "address2": null,
#           "address1": null,
#           "timezone": null,
#           "ip": null
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": null,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": null,
#           "historic_clv": null,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GR3ZVQEW3QVTXKCRN4XD",
#       "attributes": {
#         "first_name": "John",
#         "location": {
#           "longitude": null,
#           "city": "Boston",
#           "country": "USA",
#           "region": "MA",
#           "latitude": null,
#           "zip": "02111",
#           "address2": "12th floor",
#           "address1": "125 Summer St",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": null,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": null,
#           "historic_clv": null,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GRZV0M6R2SETYF8SASBF",
#       "attributes": {
#         "first_name": "Henry",
#         "location": {
#           "longitude": null,
#           "city": "Boston",
#           "country": "USA",
#           "region": "MA",
#           "latitude": null,
#           "zip": "02111",
#           "address2": "6th floor",
#           "address1": "225 Franklin St",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": null,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": null,
#           "historic_clv": null,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GS4RR8XX4WBRG72XSGVM",
#       "attributes": {
#         "first_name": "Sarah",
#         "location": {
#           "longitude": null,
#           "city": "New York",
#           "country": "USA",
#           "region": "NY",
#           "latitude": null,
#           "zip": "10017",
#           "address2": "1st floor",
#           "address1": "89 E 42nd St",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": null,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": null,
#           "historic_clv": null,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GS8MG701Z9B47JS2TRFH",
#       "attributes": {
#         "first_name": "Lindsey",
#         "location": {
#           "longitude": null,
#           "city": "Cincinnati",
#           "country": "USA",
#           "region": "OH",
#           "latitude": null,
#           "zip": "45202",
#           "address2": "Unit 600",
#           "address1": "302 W 3rd St",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": null,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": null,
#           "historic_clv": null,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSCTZCB0N1KHHKM0DEDT",
#       "attributes": {
#         "first_name": "Amanda",
#         "location": {
#           "longitude": null,
#           "city": "Atlanta",
#           "country": "USA",
#           "region": "GA",
#           "latitude": null,
#           "zip": "30313",
#           "address2": "Ste 302",
#           "address1": "285 Andrew Young International Blvd",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": null,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": null,
#           "historic_clv": null,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSGWAV25R4F5614V6Q35",
#       "attributes": {
#         "first_name": "Stacey",
#         "location": {
#           "longitude": null,
#           "city": "Inglewood",
#           "country": "USA",
#           "region": "CA",
#           "latitude": null,
#           "zip": "90303",
#           "address2": "Unit 1",
#           "address1": "3950 W Century Blvd",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": 1.0,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": 29.98,
#           "historic_clv": 29.98,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSMSQPJV38BXHY4XB8F0",
#       "attributes": {
#         "first_name": "Ben",
#         "location": {
#           "longitude": null,
#           "city": "Portland",
#           "country": "USA",
#           "region": "OR",
#           "latitude": null,
#           "zip": "97232",
#           "address2": "Ste 200",
#           "address1": "1225 NE 2nd Ave",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": 1.0,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": 29.98,
#           "historic_clv": 29.98,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSRK6X9WGVG2BB0WW2D7",
#       "attributes": {
#         "first_name": "Sam",
#         "location": {
#           "longitude": null,
#           "city": "Chicago",
#           "country": "USA",
#           "region": "IL",
#           "latitude": null,
#           "zip": "60612",
#           "address2": "Unit 2",
#           "address1": "2102 W Monroe St",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": 1.0,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": 29.98,
#           "historic_clv": 29.98,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSWGAR4YQYF69KNR164W",
#       "attributes": {
#         "first_name": "Julie",
#         "location": {
#           "longitude": null,
#           "city": "San Francisco",
#           "country": "USA",
#           "region": "CA",
#           "latitude": null,
#           "zip": "94158",
#           "address2": "9th floor",
#           "address1": "1800 Owens St",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": 1.0,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": 29.98,
#           "historic_clv": 29.98,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GT0FN4R12XPD424QB1GF",
#       "attributes": {
#         "first_name": "Matt",
#         "location": {
#           "longitude": null,
#           "city": "Boston",
#           "country": "USA",
#           "region": "MA",
#           "latitude": null,
#           "zip": "02111",
#           "address2": "6th floor",
#           "address1": "125 Summer St",
#           "timezone": null,
#           "ip": "166.137.246.54"
#         },
#         "predictive_analytics": {
#           "historic_number_of_orders": 1.0,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": 29.98,
#           "historic_clv": 29.98,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/profiles?additional-fields%5Bprofile%5D=predictive_analytics&fields%5Bprofile%5D=first_name,location&page%5Bsize%5D=20&sort=created",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
        lists_for_profile = klaviyo.Profiles.get_lists_for_profile (
                    id = '01JNT5GR3ZVQEW3QVTXKCRN4XD', 
                    fields_list = ['name', 'opt_in_process']
        )

        show_json(lists_for_profile)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "list",
#       "id": "TijKGM",
#       "attributes": {
#         "name": "Sample Data List",
#         "opt_in_process": "double_opt_in"
#       },
#       "relationships": {
#         "profiles": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/TijKGM/relationships/profiles/",
#             "related": "https://a.klaviyo.com/api/lists/TijKGM/profiles/"
#           }
#         },
#         "tags": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/TijKGM/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/lists/TijKGM/tags/"
#           }
#         },
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/TijKGM/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/lists/TijKGM/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/lists/TijKGM/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/lists?fields%5Blist%5D=name,opt_in_process",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    segements_for_profile = klaviyo.Profiles.get_segments_for_profile (
                id ='01JNT5GR3ZVQEW3QVTXKCRN4XD', 
                fields_segment = ['name', 'is_active']
    )
    show_json(segements_for_profile)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/segments?fields%5Bsegment%5D=name,is_active",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    bulk_import_profiles = klaviyo.Profiles.get_bulk_import_profiles_jobs(
        fields_profile_bulk_import_job = ['status', 'total_count'],
        filter = None,
        page_cursor = None,
        page_size = 20,
        sort = 'created_at'
    )
    show_json(bulk_import_profiles)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/profile-bulk-import-jobs?fields%5Bprofile-bulk-import-job%5D=status,total_count&page%5Bsize%5D=20&sort=created_at",
#     "next": null,
#     "prev": null
#   }
# }

# %% [markdown]
# ### Reviews

# %%
try:
    reviews = klaviyo.Reviews.get_reviews(
        fields_event = ['timestamp','event_properties'], 
        fields_review = ['email'], 
        filter = None,
        include = ['events'],
        page_cursor = None,
        page_size = 20,
        sort = 'rating'
    )
    show_json(reviews)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [],
#   "included": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/reviews?fields%5Bevent%5D=timestamp,event_properties&fields%5Breview%5D=email&include=events&page%5Bsize%5D=20&sort=rating",
#     "next": null,
#     "prev": null
#   }
# }

# %% [markdown]
# ### Campaigns

# %%
try:
    campaigns = klaviyo.Campaigns.get_campaigns(
        filter = "equals(messages.channel,'email')", 
        fields_campaign = ['name','archived'], 
        fields_tag = ['name'],
        include = ['tags'], 
        page_cursor = None, 
        sort = None
    )
    show_json(campaigns)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "campaign",
#       "id": "01JNT5GT3XNQ5HEBWZZ97J54CK",
#       "attributes": {
#         "name": "Internal Klaviyo - Test Campaign Name",
#         "archived": false
#       },
#       "relationships": {
#         "campaign-messages": {
#           "data": [
#             {
#               "type": "campaign-message",
#               "id": "01JNT5GT4458BXAJYSV20QT3Y4"
#             }
#           ],
#           "links": {
#             "self": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/relationships/campaign-messages/",
#             "related": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/campaign-messages/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/tags/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/"
#       }
#     }
#   ],
#   "included": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/campaigns?fields%5Bcampaign%5D=name,archived&fields%5Btag%5D=name&filter=equals%28messages.channel%2C%27email%27%29&include=tags",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    mssgs_for_campaigns = klaviyo.Campaigns.get_messages_for_campaign(
        id = "01JNT5GT3XNQ5HEBWZZ97J54CK", 
        fields_campaign = ['name','status'], 
        fields_image = ['image_url'], 
        fields_template = ['name','editor_type'], 
        include = ['campaign','image','template']
    )
    show_json(mssgs_for_campaigns)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "campaign-message",
#       "id": "01JNT5GT4458BXAJYSV20QT3Y4",
#       "attributes": {
#         "definition": {
#           "channel": "email",
#           "label": "Internal Klaviyo - Test Campaign Name",
#           "content": {
#             "subject": "",
#             "preview_text": "",
#             "from_email": "devx@klaviyo.com",
#             "from_label": "Internal Klaviyo",
#             "reply_to_email": null,
#             "cc_email": null,
#             "bcc_email": null
#           }
#         },
#         "send_times": [],
#         "created_at": "2025-03-08T06:01:46+00:00",
#         "updated_at": "2025-03-08T06:01:46+00:00"
#       },
#       "relationships": {
#         "campaign": {
#           "data": {
#             "type": "campaign",
#             "id": "01JNT5GT3XNQ5HEBWZZ97J54CK"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/campaign-messages/01JNT5GT4458BXAJYSV20QT3Y4/relationships/campaign/",
#             "related": "https://a.klaviyo.com/api/campaign-messages/01JNT5GT4458BXAJYSV20QT3Y4/campaign/"
#           }
#         },
#         "template": {
#           "data": null,
#           "links": {
#             "self": "https://a.klaviyo.com/api/campaign-messages/01JNT5GT4458BXAJYSV20QT3Y4/relationships/template/",
#             "related": "https://a.klaviyo.com/api/campaign-messages/01JNT5GT4458BXAJYSV20QT3Y4/template/"
#           }
#         },
#         "image": {
#           "data": null,
#           "links": {
#             "self": "https://a.klaviyo.com/api/campaign-messages/01JNT5GT4458BXAJYSV20QT3Y4/relationships/image/",
#             "related": "https://a.klaviyo.com/api/campaign-messages/01JNT5GT4458BXAJYSV20QT3Y4/image/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/campaign-messages/01JNT5GT4458BXAJYSV20QT3Y4/"
#       }
#     }
#   ],
#   "included": [
#     {
#       "type": "campaign",
#       "id": "01JNT5GT3XNQ5HEBWZZ97J54CK",
#       "attributes": {
#         "name": "Internal Klaviyo - Test Campaign Name",
#         "status": "Sent"
#       },
#       "relationships": {
#         "campaign-messages": {
#           "data": [
#             {
#               "type": "campaign-message",
#               "id": "01JNT5GT4458BXAJYSV20QT3Y4"
#             }
#           ],
#           "links": {
#             "self": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/relationships/campaign-messages/",
#             "related": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/campaign-messages/"
#           }
#         },
#         "tags": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/tags/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/campaigns/01JNT5GT3XNQ5HEBWZZ97J54CK/campaign-messages?fields%5Bcampaign%5D=name,status&fields%5Bimage%5D=image_url&fields%5Btemplate%5D=name,editor_type&include=campaign,image,template"
#   }
# }

# %%
try:
    template_for_campaign_mssg = klaviyo.Campaigns.get_template_for_campaign_message(
        id = "01JNT5GT4458BXAJYSV20QT3Y4", 
        fields_template = ['name','created', 'updated']
    )
    show_json(template_for_campaign_mssg)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": null
# }

# %% [markdown]
# ### Categories

# %%
try:
    categories = klaviyo.Catalogs.get_catalog_categories(
              fields_catalog_category = ['external_id','name'],
              filter = None ,
              page_cursor = None,
              sort = 'created',
    )
    show_json(categories)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "catalog-category",
#       "id": "$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL",
#       "attributes": {
#         "external_id": "SAMPLE-DATA-CATEGORY-APPAREL",
#         "name": "Sample Data Category Apparel"
#       },
#       "relationships": {
#         "items": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL/relationships/items/",
#             "related": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL/items/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL/"
#       }
#     },
#     {
#       "type": "catalog-category",
#       "id": "$custom:::$default:::SAMPLE-DATA-CATEGORY-NEW-ARRIVAL",
#       "attributes": {
#         "external_id": "SAMPLE-DATA-CATEGORY-NEW-ARRIVAL",
#         "name": "Sample Data Category New Arrival"
#       },
#       "relationships": {
#         "items": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-NEW-ARRIVAL/relationships/items/",
#             "related": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-NEW-ARRIVAL/items/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-NEW-ARRIVAL/"
#       }
#     },
#     {
#       "type": "catalog-category",
#       "id": "$custom:::$default:::SAMPLE-DATA-CATEGORY-SPRING",
#       "attributes": {
#         "external_id": "SAMPLE-DATA-CATEGORY-SPRING",
#         "name": "Sample Data Category Spring"
#       },
#       "relationships": {
#         "items": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-SPRING/relationships/items/",
#             "related": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-SPRING/items/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-SPRING/"
#       }
#     },
#     {
#       "type": "catalog-category",
#       "id": "$custom:::$default:::SAMPLE-DATA-CATEGORY-SUMMER",
#       "attributes": {
#         "external_id": "SAMPLE-DATA-CATEGORY-SUMMER",
#         "name": "Sample Data Category Summer"
#       },
#       "relationships": {
#         "items": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-SUMMER/relationships/items/",
#             "related": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-SUMMER/items/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-SUMMER/"
#       }
#     },
#     {
#       "type": "catalog-category",
#       "id": "$custom:::$default:::SAMPLE-DATA-CATEGORY-FALL",
#       "attributes": {
#         "external_id": "SAMPLE-DATA-CATEGORY-FALL",
#         "name": "Sample Data Category Fall"
#       },
#       "relationships": {
#         "items": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-FALL/relationships/items/",
#             "related": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-FALL/items/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-FALL/"
#       }
#     },
#     {
#       "type": "catalog-category",
#       "id": "$custom:::$default:::SAMPLE-DATA-CATEGORY-WINTER",
#       "attributes": {
#         "external_id": "SAMPLE-DATA-CATEGORY-WINTER",
#         "name": "Sample Data Category Winter"
#       },
#       "relationships": {
#         "items": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-WINTER/relationships/items/",
#             "related": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-WINTER/items/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-WINTER/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/catalog-categories?fields%5Bcatalog-category%5D=external_id,name&sort=created",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    catalog_category = klaviyo.Catalogs.get_catalog_category(
              id = "$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL",
              fields_catalog_category = ['name']
    )
    show_json(catalog_category)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": {
#     "type": "catalog-category",
#     "id": "$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL",
#     "attributes": {
#       "name": "Sample Data Category Apparel"
#     },
#     "relationships": {
#       "items": {
#         "links": {
#           "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL/relationships/items/",
#           "related": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL/items/"
#         }
#       }
#     },
#     "links": {
#       "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL/"
#     }
#   },
#   "links": {
#     "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL?fields%5Bcatalog-category%5D=name"
#   }
# }

# %%
try:
    item_ids = klaviyo.Catalogs.get_item_ids_for_catalog_category(
        id = "$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL", 
        filter = None, 
        page_cursor = None, 
        sort = 'created'
    )
    item_ids_list = [{'type': item.type.value, 'id': item.id} for item in item_ids.data ]
    show_json(item_ids_list)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# [
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-1"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-2"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-3"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-4"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-5"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-6"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-7"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-8"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-9"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-10"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-11"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-12"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-13"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-14"
#   },
#   {
#     "type": "catalog-item",
#     "id": "$custom:::$default:::SAMPLE-DATA-ITEM-15"
#   }
# ]

# %%
try:
    variants = klaviyo.Catalogs.get_catalog_variants(
        fields_catalog_variant = ['title', 'inventory_quantity'], 
        filter = None, 
        page_cursor = None, 
        sort = 'created'
    )
    show_json(variants)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-1-VARIANT-MEDIUM",
#       "attributes": {
#         "title": "Ocean Blue Shirt (Sample) Variant Medium",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-1-VARIANT-MEDIUM/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-1-VARIANT-MEDIUM/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-1-VARIANT-MEDIUM/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-1-VARIANT-LARGE",
#       "attributes": {
#         "title": "Ocean Blue Shirt (Sample) Variant Large",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-1-VARIANT-LARGE/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-1-VARIANT-LARGE/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-1-VARIANT-LARGE/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-2-VARIANT-MEDIUM",
#       "attributes": {
#         "title": "Yellow Wool Jumper (Sample) Variant Medium",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-2-VARIANT-MEDIUM/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-2-VARIANT-MEDIUM/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-2-VARIANT-MEDIUM/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-2-VARIANT-LARGE",
#       "attributes": {
#         "title": "Yellow Wool Jumper (Sample) Variant Large",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-2-VARIANT-LARGE/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-2-VARIANT-LARGE/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-2-VARIANT-LARGE/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-3-VARIANT-1",
#       "attributes": {
#         "title": "Classic Leather Jacket (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-3-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-3-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-3-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-4-VARIANT-MEDIUM",
#       "attributes": {
#         "title": "Dark Denim Top (Sample) Variant Medium",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-4-VARIANT-MEDIUM/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-4-VARIANT-MEDIUM/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-4-VARIANT-MEDIUM/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-4-VARIANT-LARGE",
#       "attributes": {
#         "title": "Dark Denim Top (Sample) Variant Large",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-4-VARIANT-LARGE/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-4-VARIANT-LARGE/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-4-VARIANT-LARGE/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-5-VARIANT-1",
#       "attributes": {
#         "title": "Navy Sports Jacket (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-5-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-5-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-5-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-6-VARIANT-MEDIUM",
#       "attributes": {
#         "title": "Soft Winter Jacket (Sample) Variant Medium",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-6-VARIANT-MEDIUM/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-6-VARIANT-MEDIUM/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-6-VARIANT-MEDIUM/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-6-VARIANT-LARGE",
#       "attributes": {
#         "title": "Soft Winter Jacket (Sample) Variant Large",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-6-VARIANT-LARGE/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-6-VARIANT-LARGE/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-6-VARIANT-LARGE/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-7-VARIANT-1",
#       "attributes": {
#         "title": "Zipped Jacket (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-7-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-7-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-7-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-8-VARIANT-1",
#       "attributes": {
#         "title": "Chequered Red Shirt (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-8-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-8-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-8-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-9-VARIANT-1",
#       "attributes": {
#         "title": "White Cotton Shirt (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-9-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-9-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-9-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-10-VARIANT-1",
#       "attributes": {
#         "title": "Olive Green Jacket (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-10-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-10-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-10-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-11-VARIANT-1",
#       "attributes": {
#         "title": "Blue Silk Tuxedo (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-11-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-11-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-11-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-12-VARIANT-1",
#       "attributes": {
#         "title": "Red Sports Tee (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-12-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-12-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-12-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-13-VARIANT-1",
#       "attributes": {
#         "title": "Striped Skirt And Top (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-13-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-13-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-13-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-14-VARIANT-1",
#       "attributes": {
#         "title": "Led High Tops (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-14-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-14-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-14-VARIANT-1/"
#       }
#     },
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-15-VARIANT-1",
#       "attributes": {
#         "title": "Classic Varsity Top (Sample) Variant 1",
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-15-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-15-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-15-VARIANT-1/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/catalog-variants?fields%5Bcatalog-variant%5D=title,inventory_quantity&sort=created",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    item_variants = klaviyo.Catalogs.get_variants_for_catalog_item(
        id = "$custom:::$default:::SAMPLE-DATA-ITEM-3", 
        fields_catalog_variant = ['title', 'inventory_policy', 'inventory_quantity'], 
        filter = None, 
        page_cursor = None, 
        sort = 'created'
    )
    show_json(item_variants)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "catalog-variant",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-3-VARIANT-1",
#       "attributes": {
#         "title": "Classic Leather Jacket (Sample) Variant 1",
#         "inventory_policy": 0,
#         "inventory_quantity": 0.0
#       },
#       "relationships": {
#         "item": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-3-VARIANT-1/relationships/item/",
#             "related": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-3-VARIANT-1/item/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-variants/$custom:::$default:::SAMPLE-DATA-ITEM-3-VARIANT-1/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-3/variants?fields%5Bcatalog-variant%5D=title,inventory_policy,inventory_quantity&sort=created",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    items = klaviyo.Catalogs.get_catalog_items(
        fields_catalog_item = ['title', 'price'], 
        filter = None, 
        include = None, 
        page_cursor = None, 
        sort = 'created'
    )
    show_json(items)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-1",
#       "attributes": {
#         "title": "Ocean Blue Shirt (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-1/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-1/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-1/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-2",
#       "attributes": {
#         "title": "Yellow Wool Jumper (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-2/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-2/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-2/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-3",
#       "attributes": {
#         "title": "Classic Leather Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-3/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-3/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-3/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-4",
#       "attributes": {
#         "title": "Dark Denim Top (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-4/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-4/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-4/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-5",
#       "attributes": {
#         "title": "Navy Sports Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-5/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-5/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-5/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-6",
#       "attributes": {
#         "title": "Soft Winter Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-6/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-6/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-6/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-7",
#       "attributes": {
#         "title": "Zipped Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-7/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-7/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-7/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-8",
#       "attributes": {
#         "title": "Chequered Red Shirt (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-8/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-8/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-8/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-9",
#       "attributes": {
#         "title": "White Cotton Shirt (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-9/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-9/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-9/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-10",
#       "attributes": {
#         "title": "Olive Green Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-10/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-10/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-10/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-11",
#       "attributes": {
#         "title": "Blue Silk Tuxedo (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-11/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-11/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-11/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-12",
#       "attributes": {
#         "title": "Red Sports Tee (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-12/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-12/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-12/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-13",
#       "attributes": {
#         "title": "Striped Skirt and Top (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-13/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-13/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-13/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-14",
#       "attributes": {
#         "title": "LED High Tops (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-14/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-14/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-14/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-15",
#       "attributes": {
#         "title": "Classic Varsity Top (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-15/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-15/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-15/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/catalog-items?fields%5Bcatalog-item%5D=title,price&sort=created",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    items_for_category = klaviyo.Catalogs.get_items_for_catalog_category(
        id = "$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL",
        fields_catalog_item = ['title', 'price'], 
        filter = None, 
        include = None, 
        page_cursor = None,
        sort = 'created'
    )

    show_json(items_for_category)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-1",
#       "attributes": {
#         "title": "Ocean Blue Shirt (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-1/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-1/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-1/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-2",
#       "attributes": {
#         "title": "Yellow Wool Jumper (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-2/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-2/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-2/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-3",
#       "attributes": {
#         "title": "Classic Leather Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-3/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-3/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-3/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-4",
#       "attributes": {
#         "title": "Dark Denim Top (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-4/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-4/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-4/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-5",
#       "attributes": {
#         "title": "Navy Sports Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-5/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-5/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-5/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-6",
#       "attributes": {
#         "title": "Soft Winter Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-6/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-6/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-6/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-7",
#       "attributes": {
#         "title": "Zipped Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-7/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-7/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-7/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-8",
#       "attributes": {
#         "title": "Chequered Red Shirt (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-8/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-8/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-8/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-9",
#       "attributes": {
#         "title": "White Cotton Shirt (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-9/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-9/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-9/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-10",
#       "attributes": {
#         "title": "Olive Green Jacket (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-10/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-10/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-10/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-11",
#       "attributes": {
#         "title": "Blue Silk Tuxedo (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-11/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-11/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-11/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-12",
#       "attributes": {
#         "title": "Red Sports Tee (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-12/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-12/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-12/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-13",
#       "attributes": {
#         "title": "Striped Skirt and Top (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-13/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-13/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-13/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-14",
#       "attributes": {
#         "title": "LED High Tops (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-14/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-14/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-14/"
#       }
#     },
#     {
#       "type": "catalog-item",
#       "id": "$custom:::$default:::SAMPLE-DATA-ITEM-15",
#       "attributes": {
#         "title": "Classic Varsity Top (Sample)",
#         "price": null
#       },
#       "relationships": {
#         "variants": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-15/relationships/variants/",
#             "related": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-15/variants/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/catalog-items/$custom:::$default:::SAMPLE-DATA-ITEM-15/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/catalog-categories/$custom:::$default:::SAMPLE-DATA-CATEGORY-APPAREL/items?fields%5Bcatalog-item%5D=title,price&sort=created",
#     "next": null,
#     "prev": null
#   }
# }

# %% [markdown]
# ### Segments

# %%
try:
    segments = klaviyo.Segments.get_segments(
        fields_segment = ['name','is_active'], 
        fields_tag = ['name'], 
        filter = None,
        include = ['tags'], 
        page_cursor = None, 
        sort = 'name'
    )
    show_json(segments)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "segment",
#       "id": "WEmvLP",
#       "attributes": {
#         "name": "Engaged (30 Days)",
#         "is_active": true
#       },
#       "relationships": {
#         "profiles": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/WEmvLP/relationships/profiles/",
#             "related": "https://a.klaviyo.com/api/segments/WEmvLP/profiles/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/WEmvLP/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/segments/WEmvLP/tags/"
#           }
#         },
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/WEmvLP/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/segments/WEmvLP/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/segments/WEmvLP/"
#       }
#     },
#     {
#       "type": "segment",
#       "id": "YsMphi",
#       "attributes": {
#         "name": "Engaged (60 Days)",
#         "is_active": true
#       },
#       "relationships": {
#         "profiles": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/YsMphi/relationships/profiles/",
#             "related": "https://a.klaviyo.com/api/segments/YsMphi/profiles/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/YsMphi/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/segments/YsMphi/tags/"
#           }
#         },
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/YsMphi/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/segments/YsMphi/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/segments/YsMphi/"
#       }
#     },
#     {
#       "type": "segment",
#       "id": "UeUzDH",
#       "attributes": {
#         "name": "Engaged (90 Days)",
#         "is_active": true
#       },
#       "relationships": {
#         "profiles": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/UeUzDH/relationships/profiles/",
#             "related": "https://a.klaviyo.com/api/segments/UeUzDH/profiles/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/UeUzDH/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/segments/UeUzDH/tags/"
#           }
#         },
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/UeUzDH/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/segments/UeUzDH/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/segments/UeUzDH/"
#       }
#     },
#     {
#       "type": "segment",
#       "id": "T5vJKR",
#       "attributes": {
#         "name": "New Subscribers",
#         "is_active": true
#       },
#       "relationships": {
#         "profiles": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/T5vJKR/relationships/profiles/",
#             "related": "https://a.klaviyo.com/api/segments/T5vJKR/profiles/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/T5vJKR/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/segments/T5vJKR/tags/"
#           }
#         },
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/segments/T5vJKR/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/segments/T5vJKR/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/segments/T5vJKR/"
#       }
#     }
#   ],
#   "included": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/segments?fields%5Bsegment%5D=name,is_active&fields%5Btag%5D=name&include=tags&sort=name",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    profiles_for_segments = klaviyo.Segments.get_profiles_for_segment(
        id = "YsMphi", 
        additional_fields_profile = ['predictive_analytics'], 
        fields_profile = ['first_name', 'last_name', 'email'], 
        filter = None, 
        page_cursor = None, 
        page_size = None, 
        sort = 'joined_group_at'
    )
    show_json(profiles_for_segments)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "profile",
#       "id": "01JNT4KAWQX1G11QYMR5Y17A5M",
#       "attributes": {
#         "first_name": null,
#         "last_name": null,
#         "email": "sherwin.varghese@neenopal.com",
#         "predictive_analytics": {
#           "historic_number_of_orders": null,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": null,
#           "historic_clv": null,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/segments/YsMphi/profiles?additional-fields%5Bprofile%5D=predictive_analytics&fields%5Bprofile%5D=first_name,last_name,email&sort=joined_group_at",
#     "next": null,
#     "prev": null
#   }
# }

# %% [markdown]
# ### Events

# %%
try:
    events = klaviyo.Events.get_events(
        fields_event = ['timestamp', 'event_properties'], 
        fields_metric = ['name', 'integration'], 
        fields_profile = ['first_name', 'last_name', 'email'], 
        filter = None, 
        include = ['metric', 'profile'], 
        page_cursor = None, 
        sort = None
    )
    show_json(events)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "event",
#       "id": "5ZeQ8vBSRiy",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "browser": "Firefox",
#           "os": "Windows",
#           "page": "http://www.example.com/landing",
#           "$event_id": "sample_data_gen:cf07b790-4f8b-4dfb-941a-3fd359c5c624"
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8vBSRiy/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8vBSRiy/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "V7Ppiw"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8vBSRiy/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8vBSRiy/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ8vBSRiy/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ8vBSChP",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "OrderId": "1235",
#           "ProductID": "1112",
#           "SKU": "TALEOFTWO",
#           "ProductName": "A Tale of Two Cities",
#           "Quantity": 1,
#           "ProductURL": "http://www.example.com/path/to/product",
#           "ImageURL": "http://www.example.com/path/to/product/image.png",
#           "Categories": [
#             "Fiction",
#             "Classics"
#           ],
#           "ProductBrand": "Harcourt Classics",
#           "$event_id": "sample_data_gen:13dc90e1-c0bc-400f-867b-4928c708ae49",
#           "$value": 19.99
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8vBSChP/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8vBSChP/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "TQHxY2"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8vBSChP/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8vBSChP/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ8vBSChP/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ6hjA3Xx",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "OrderId": "1234",
#           "Reason": "No longer needed",
#           "Categories": [
#             "Fiction",
#             "Classics",
#             "Children"
#           ],
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "Brands": [
#             "Kids Books",
#             "Harcourt Classics"
#           ],
#           "Discount Code": "Free Shipping",
#           "Discount Value": 5,
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "Categories": [
#                 "Fiction",
#                 "Children"
#               ],
#               "Brand": "Kids Books"
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "Categories": [
#                 "Fiction",
#                 "Classics"
#               ],
#               "Brand": "Harcourt Classics"
#             }
#           ],
#           "BillingAddress": {
#             "FirstName": "Matt",
#             "LastName": "Kemp (Sample)",
#             "Company": "",
#             "Address1": "125 Summer St",
#             "Address2": "6th floor",
#             "City": "Boston",
#             "Region": "Massachusetts",
#             "RegionCode": "MA",
#             "Country": "USA",
#             "CountryCode": "US",
#             "Zip": "02111",
#             "Phone": "5005550006"
#           },
#           "ShippingAddress": {
#             "FirstName": "Matt",
#             "LastName": "Kemp (Sample)",
#             "Company": "",
#             "Address1": "125 Summer St",
#             "Address2": "6th floor",
#             "City": "Boston",
#             "Region": "Massachusetts",
#             "RegionCode": "MA",
#             "Country": "USA",
#             "CountryCode": "US",
#             "Zip": "02111",
#             "Phone": "5005550006"
#           },
#           "$event_id": "sample_data_gen:bda4b910-d197-4b50-861e-c7ca42e22d23",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6hjA3Xx/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6hjA3Xx/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "V28nRS"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6hjA3Xx/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6hjA3Xx/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ6hjA3Xx/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ6gQhyrA",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "OrderId": "1234",
#           "Reason": "No longer needed",
#           "Categories": [
#             "Fiction",
#             "Classics",
#             "Children"
#           ],
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "Brands": [
#             "Kids Books",
#             "Harcourt Classics"
#           ],
#           "Discount Code": "Free Shipping",
#           "Discount Value": 5,
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "Categories": [
#                 "Fiction",
#                 "Children"
#               ],
#               "Brand": "Kids Books"
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "Categories": [
#                 "Fiction",
#                 "Classics"
#               ],
#               "Brand": "Harcourt Classics"
#             }
#           ],
#           "BillingAddress": {
#             "FirstName": "Matt",
#             "LastName": "Kemp (Sample)",
#             "Company": "",
#             "Address1": "125 Summer St",
#             "Address2": "6th floor",
#             "City": "Boston",
#             "Region": "Massachusetts",
#             "RegionCode": "MA",
#             "Country": "USA",
#             "CountryCode": "US",
#             "Zip": "02111",
#             "Phone": "5005550006"
#           },
#           "ShippingAddress": {
#             "FirstName": "Matt",
#             "LastName": "Kemp (Sample)",
#             "Company": "",
#             "Address1": "125 Summer St",
#             "Address2": "6th floor",
#             "City": "Boston",
#             "Region": "Massachusetts",
#             "RegionCode": "MA",
#             "Country": "USA",
#             "CountryCode": "US",
#             "Zip": "02111",
#             "Phone": "5005550006"
#           },
#           "$event_id": "sample_data_gen:4a87dc78-f7a2-4365-99c3-beaaf6b8e4bb",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6gQhyrA/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6gQhyrA/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "RrgBQU"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6gQhyrA/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6gQhyrA/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ6gQhyrA/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZePNGQZY56",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "ProductName": "Winnie the Pooh",
#           "ProductID": "1111",
#           "Categories": [
#             "Fiction",
#             "Children"
#           ],
#           "ImageURL": "http://www.example.com/path/to/product/image.png",
#           "URL": "http://www.example.com/path/to/product",
#           "Brand": "Kids Books",
#           "Price": 9.99,
#           "CompareAtPrice": 14.99,
#           "$event_id": "sample_data_gen:f9daa19c-fc80-46da-892d-43d671693aab"
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePNGQZY56/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZePNGQZY56/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "UtJAAD"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePNGQZY56/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZePNGQZY56/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZePNGQZY56/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZePNGmH6UJ",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "OrderId": "1234",
#           "Categories": [
#             "Fiction",
#             "Classics",
#             "Children"
#           ],
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "Brands": [
#             "Kids Books",
#             "Harcourt Classics"
#           ],
#           "DiscountCode": "Free Shipping",
#           "DiscountValue": 5,
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "Categories": [
#                 "Fiction",
#                 "Children"
#               ],
#               "Brand": "Kids Books"
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "Categories": [
#                 "Fiction",
#                 "Classics"
#               ],
#               "Brand": "Harcourt Classics"
#             }
#           ],
#           "BillingAddress": {
#             "FirstName": "Matt",
#             "LastName": "Kemp (Sample)",
#             "Company": "",
#             "Address1": "125 Summer St",
#             "Address2": "6th floor",
#             "City": "Boston",
#             "Region": "Massachusetts",
#             "RegionCode": "MA",
#             "Country": "USA",
#             "CountryCode": "US",
#             "Zip": "02111",
#             "Phone": "5005550006"
#           },
#           "ShippingAddress": {
#             "FirstName": "Matt",
#             "LastName": "Kemp (Sample)",
#             "Company": "",
#             "Address1": "125 Summer St",
#             "Address2": "6th floor",
#             "City": "Boston",
#             "Region": "Massachusetts",
#             "RegionCode": "MA",
#             "Country": "USA",
#             "CountryCode": "US",
#             "Zip": "02111",
#             "Phone": "5005550006"
#           },
#           "$event_id": "sample_data_gen:62d38516-0a44-43e9-852a-98c11e81f833",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePNGmH6UJ/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZePNGmH6UJ/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "VD9ruv"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePNGmH6UJ/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZePNGmH6UJ/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZePNGmH6UJ/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZePMyZjxPy",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "CheckoutURL": "http://www.example.com/path/to/checkout",
#           "Categories": [
#             "Fiction",
#             "Children",
#             "Classics"
#           ],
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Children"
#               ]
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Classics"
#               ]
#             }
#           ],
#           "$event_id": "sample_data_gen:a9c4ac9c-01ea-4982-bec2-d3277da10706",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePMyZjxPy/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZePMyZjxPy/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "S4hEtx"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePMyZjxPy/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZePMyZjxPy/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZePMyZjxPy/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZePLtA7Pka",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "AddedItemProductName": "A Tale of Two Cities",
#           "AddedItemProductID": "1112",
#           "AddedItemSKU": "TALEOFTWO",
#           "AddedItemCategories": [
#             "Fiction",
#             "Classics"
#           ],
#           "AddedItemImageURL": "http://www.example.com/path/to/product/image2.png",
#           "AddedItemURL": "http://www.example.com/path/to/product2",
#           "AddedItemPrice": 19.99,
#           "AddedItemQuantity": 1,
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "CheckoutURL": "http://www.example.com/path/to/checkout",
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Children"
#               ]
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Classics"
#               ]
#             }
#           ],
#           "$event_id": "sample_data_gen:1322523b-a71d-4639-b128-58ad4da4902f",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePLtA7Pka/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZePLtA7Pka/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "Y4AmBB"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePLtA7Pka/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZePLtA7Pka/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZePLtA7Pka/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZePKnaU559",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "ProductName": "A Tale of Two Cities",
#           "ProductID": "1112",
#           "Categories": [
#             "Fiction",
#             "Classics"
#           ],
#           "ImageURL": "http://www.example.com/path/to/product/image.png",
#           "URL": "http://www.example.com/path/to/product",
#           "Brand": "Harcourt Classics",
#           "Price": 19.99,
#           "CompareAtPrice": 19.99,
#           "$event_id": "sample_data_gen:8edbb0b3-9ef4-421a-ada8-80dd282734de"
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePKnaU559/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZePKnaU559/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "UtJAAD"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePKnaU559/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZePKnaU559/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZePKnaU559/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZePKkH2psA",
#       "attributes": {
#         "timestamp": 1741413709,
#         "event_properties": {
#           "OrderId": "1234",
#           "ProductID": "1111",
#           "SKU": "WINNIEPOOH",
#           "ProductName": "Winnie the Pooh",
#           "Quantity": 1,
#           "ProductURL": "http://www.example.com/path/to/product",
#           "ImageURL": "http://www.example.com/path/to/product/image.png",
#           "Categories": [
#             "Fiction",
#             "Children"
#           ],
#           "ProductBrand": "Kids Books",
#           "$event_id": "sample_data_gen:8d7cb736-ba65-48b8-8602-8acce9220d18",
#           "$value": 9.99
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GT0FN4R12XPD424QB1GF"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePKkH2psA/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZePKkH2psA/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "TQHxY2"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZePKkH2psA/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZePKkH2psA/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZePKkH2psA/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ8x5LrQZ",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "AddedItemProductName": "A Tale of Two Cities",
#           "AddedItemProductID": "1112",
#           "AddedItemSKU": "TALEOFTWO",
#           "AddedItemCategories": [
#             "Fiction",
#             "Classics"
#           ],
#           "AddedItemImageURL": "http://www.example.com/path/to/product/image2.png",
#           "AddedItemURL": "http://www.example.com/path/to/product2",
#           "AddedItemPrice": 19.99,
#           "AddedItemQuantity": 1,
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "CheckoutURL": "http://www.example.com/path/to/checkout",
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Children"
#               ]
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Classics"
#               ]
#             }
#           ],
#           "$event_id": "sample_data_gen:e79b34bb-38e8-4d5e-a432-1aa8016a0915",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSMSQPJV38BXHY4XB8F0"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8x5LrQZ/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8x5LrQZ/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "Y4AmBB"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8x5LrQZ/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8x5LrQZ/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ8x5LrQZ/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ8w7bn5E",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "browser": "Firefox",
#           "os": "Windows",
#           "page": "http://www.example.com/landing",
#           "$event_id": "sample_data_gen:5094fd90-d260-4fd1-b821-b6ff22f43233"
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSRK6X9WGVG2BB0WW2D7"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8w7bn5E/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8w7bn5E/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "V7Ppiw"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8w7bn5E/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8w7bn5E/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ8w7bn5E/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ8w7aSu3",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "browser": "Firefox",
#           "os": "Windows",
#           "page": "http://www.example.com/landing",
#           "$event_id": "sample_data_gen:7f1ece96-181c-4779-bc09-4bdf0a2ccec8"
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSWGAR4YQYF69KNR164W"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8w7aSu3/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8w7aSu3/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "V7Ppiw"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8w7aSu3/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8w7aSu3/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ8w7aSu3/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ8vBSzLx",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "AddedItemProductName": "A Tale of Two Cities",
#           "AddedItemProductID": "1112",
#           "AddedItemSKU": "TALEOFTWO",
#           "AddedItemCategories": [
#             "Fiction",
#             "Classics"
#           ],
#           "AddedItemImageURL": "http://www.example.com/path/to/product/image2.png",
#           "AddedItemURL": "http://www.example.com/path/to/product2",
#           "AddedItemPrice": 19.99,
#           "AddedItemQuantity": 1,
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "CheckoutURL": "http://www.example.com/path/to/checkout",
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Children"
#               ]
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Classics"
#               ]
#             }
#           ],
#           "$event_id": "sample_data_gen:61cee63c-c29b-4c99-a496-7a119b517ee2",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSWGAR4YQYF69KNR164W"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8vBSzLx/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8vBSzLx/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "Y4AmBB"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ8vBSzLx/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ8vBSzLx/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ8vBSzLx/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ7rbgnaf",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "CheckoutURL": "http://www.example.com/path/to/checkout",
#           "Categories": [
#             "Fiction",
#             "Children",
#             "Classics"
#           ],
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Children"
#               ]
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Classics"
#               ]
#             }
#           ],
#           "$event_id": "sample_data_gen:10717484-b86f-48c8-a67b-041b62c6f50f",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSMSQPJV38BXHY4XB8F0"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ7rbgnaf/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ7rbgnaf/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "S4hEtx"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ7rbgnaf/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ7rbgnaf/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ7rbgnaf/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ7rbfP6h",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "OrderId": "1234",
#           "Categories": [
#             "Fiction",
#             "Classics",
#             "Children"
#           ],
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "Brands": [
#             "Kids Books",
#             "Harcourt Classics"
#           ],
#           "Discount Code": "Free Shipping",
#           "Discount Value": 5,
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "Categories": [
#                 "Fiction",
#                 "Children"
#               ],
#               "Brand": "Kids Books"
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "Categories": [
#                 "Fiction",
#                 "Classics"
#               ],
#               "Brand": "Harcourt Classics"
#             }
#           ],
#           "BillingAddress": {
#             "FirstName": "Sam",
#             "LastName": "Marco (Sample)",
#             "Company": "",
#             "Address1": "2102 W Monroe St",
#             "Address2": "Unit 2",
#             "City": "Chicago",
#             "Region": "Illinois",
#             "RegionCode": "IL",
#             "Country": "USA",
#             "CountryCode": "US",
#             "Zip": "60612",
#             "Phone": "5005550006"
#           },
#           "ShippingAddress": {
#             "FirstName": "Sam",
#             "LastName": "Marco (Sample)",
#             "Company": "",
#             "Address1": "2102 W Monroe St",
#             "Address2": "Unit 2",
#             "City": "Chicago",
#             "Region": "Illinois",
#             "RegionCode": "IL",
#             "Country": "USA",
#             "CountryCode": "US",
#             "Zip": "60612",
#             "Phone": "5005550006"
#           },
#           "$event_id": "sample_data_gen:641ec6bd-8b7c-4c4d-92bb-929dafa645d4",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSRK6X9WGVG2BB0WW2D7"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ7rbfP6h/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ7rbfP6h/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "XrziYY"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ7rbfP6h/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ7rbfP6h/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ7rbfP6h/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ6iMtEt5",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "AddedItemProductName": "A Tale of Two Cities",
#           "AddedItemProductID": "1112",
#           "AddedItemSKU": "TALEOFTWO",
#           "AddedItemCategories": [
#             "Fiction",
#             "Classics"
#           ],
#           "AddedItemImageURL": "http://www.example.com/path/to/product/image2.png",
#           "AddedItemURL": "http://www.example.com/path/to/product2",
#           "AddedItemPrice": 19.99,
#           "AddedItemQuantity": 1,
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "CheckoutURL": "http://www.example.com/path/to/checkout",
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Children"
#               ]
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Classics"
#               ]
#             }
#           ],
#           "$event_id": "sample_data_gen:a06f88d9-b70d-40fd-9ce9-2b4ace060666",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSRK6X9WGVG2BB0WW2D7"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6iMtEt5/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6iMtEt5/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "Y4AmBB"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6iMtEt5/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6iMtEt5/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ6iMtEt5/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ6hNSErK",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "OrderId": "1234",
#           "ProductID": "1111",
#           "SKU": "WINNIEPOOH",
#           "ProductName": "Winnie the Pooh",
#           "Quantity": 1,
#           "ProductURL": "http://www.example.com/path/to/product",
#           "ImageURL": "http://www.example.com/path/to/product/image.png",
#           "Categories": [
#             "Fiction",
#             "Children"
#           ],
#           "ProductBrand": "Kids Books",
#           "$event_id": "sample_data_gen:0851552c-dfb5-4866-9ab6-cf8ac6d5c21f",
#           "$value": 9.99
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSRK6X9WGVG2BB0WW2D7"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6hNSErK/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6hNSErK/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "TQHxY2"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6hNSErK/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6hNSErK/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ6hNSErK/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ6gQhmmp",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "CheckoutURL": "http://www.example.com/path/to/checkout",
#           "Categories": [
#             "Fiction",
#             "Children",
#             "Classics"
#           ],
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Children"
#               ]
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Classics"
#               ]
#             }
#           ],
#           "$event_id": "sample_data_gen:b10b4b47-7e89-403c-adec-783dcd6b0ee2",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSWGAR4YQYF69KNR164W"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6gQhmmp/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6gQhmmp/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "S4hEtx"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ6gQhmmp/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ6gQhmmp/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ6gQhmmp/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ5cpEVGj",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "CheckoutURL": "http://www.example.com/path/to/checkout",
#           "Categories": [
#             "Fiction",
#             "Children",
#             "Classics"
#           ],
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Children"
#               ]
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
#               "ProductURL": "http://www.example.com/path/to/product2",
#               "ImageURL": "http://www.example.com/path/to/product/image2.png",
#               "ProductCategories": [
#                 "Fiction",
#                 "Classics"
#               ]
#             }
#           ],
#           "$event_id": "sample_data_gen:014166bd-ba96-4bf5-b85d-877e9c63b95c",
#           "$value": 29.98
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSRK6X9WGVG2BB0WW2D7"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGj/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGj/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "S4hEtx"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGj/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGj/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGj/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ5cpEVGe",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "OrderId": "1235",
#           "ProductID": "1112",
#           "SKU": "TALEOFTWO",
#           "ProductName": "A Tale of Two Cities",
#           "Quantity": 1,
#           "ProductURL": "http://www.example.com/path/to/product",
#           "ImageURL": "http://www.example.com/path/to/product/image.png",
#           "Categories": [
#             "Fiction",
#             "Classics"
#           ],
#           "ProductBrand": "Harcourt Classics",
#           "$event_id": "sample_data_gen:42758a98-2c73-497f-980b-60d34ac489b4",
#           "$value": 19.99
#         }
#       },
#       "relationships": {
#         "profile": {
#           "data": {
#             "type": "profile",
#             "id": "01JNT5GSGWAV25R4F5614V6Q35"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGe/relationships/profile/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGe/profile/"
#           }
#         },
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "TQHxY2"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGe/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGe/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/events/5ZeQ5cpEVGe/"
#       }
#     },
#     {
#       "type": "event",
#       "id": "5ZeQ5cpEH2M",
#       "attributes": {
#         "timestamp": 1741413708,
#         "event_properties": {
#           "OrderId": "1234",
#           "Categories": [
#             "Fiction",
#             "Classics",
#             "Children"
#           ],
#           "ItemNames": [
#             "Winnie the Pooh",
#             "A Tale of Two Cities"
#           ],
#           "Brands": [
#             "Kids Books",
#             "Harcourt Classics"
#           ],
#           "DiscountCode": "Free Shipping",
#           "DiscountValue": 5,
#           "Items": [
#             {
#               "ProductID": "1111",
#               "SKU": "WINNIEPOOH",
#               "ProductName": "Winnie the Pooh",
#               "Quantity": 1,
#               "ItemPrice": 9.99,
#               "RowTotal": 9.99,
#               "ProductURL": "http://www.example.com/path/to/product",
#               "ImageURL": "http://www.example.com/path/to/product/image.png",
#               "Categories": [
#                 "Fiction",
#                 "Children"
#               ],
#               "Brand": "Kids Books"
#             },
#             {
#               "ProductID": "1112",
#               "SKU": "TALEOFTWO",
#               "ProductName": "A Tale of Two Cities",
#               "Quantity": 1,
#               "ItemPrice": 19.99,
#               "RowTotal": 19.99,
# ...
#         }
#       },
#       "relationships": {
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/RU6TRZ/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/RU6TRZ/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/RU6TRZ/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "VuWESX",
#       "attributes": {
#         "name": "Failed to Deliver Automated Response SMS",
#         "integration": {
#           "object": "integration",
#           "id": "0rG4eQ",
#           "key": "klaviyo",
#           "name": "Klaviyo",
#           "category": "Internal"
#         }
#       },
#       "relationships": {
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/VuWESX/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/VuWESX/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/VuWESX/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "W7XHvA",
#       "attributes": {
#         "name": "Unsubscribed from SMS Marketing",
#         "integration": {
#           "object": "integration",
#           "id": "0rG4eQ",
#           "key": "klaviyo",
#           "name": "Klaviyo",
#           "category": "Internal"
#         }
#       },
#       "relationships": {
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/W7XHvA/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/W7XHvA/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/W7XHvA/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "UuNkFT",
#       "attributes": {
#         "name": "Clicked email to unsubscribe",
#         "integration": {
#           "object": "integration",
#           "id": "0rG4eQ",
#           "key": "klaviyo",
#           "name": "Klaviyo",
#           "category": "Internal"
#         }
#       },
#       "relationships": {
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/UuNkFT/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/UuNkFT/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/UuNkFT/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "TGwMnu",
#       "attributes": {
#         "name": "Received Automated Response SMS",
#         "integration": {
#           "object": "integration",
#           "id": "0rG4eQ",
#           "key": "klaviyo",
#           "name": "Klaviyo",
#           "category": "Internal"
#         }
#       },
#       "relationships": {
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/TGwMnu/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/TGwMnu/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/TGwMnu/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "UjxPZ7",
#       "attributes": {
#         "name": "Failed to Deliver SMS",
#         "integration": {
#           "object": "integration",
#           "id": "0rG4eQ",
#           "key": "klaviyo",
#           "name": "Klaviyo",
#           "category": "Internal"
#         }
#       },
#       "relationships": {
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/UjxPZ7/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/UjxPZ7/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/UjxPZ7/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GT0FN4R12XPD424QB1GF",
#       "attributes": {
#         "first_name": "Matt",
#         "last_name": "Kemp (Sample)",
#         "email": "matt.kemp@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GT0FN4R12XPD424QB1GF/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSMSQPJV38BXHY4XB8F0",
#       "attributes": {
#         "first_name": "Ben",
#         "last_name": "Kennedy (Sample)",
#         "email": "ben.kennedy@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSMSQPJV38BXHY4XB8F0/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSRK6X9WGVG2BB0WW2D7",
#       "attributes": {
#         "first_name": "Sam",
#         "last_name": "Marco (Sample)",
#         "email": "sam.marco@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSRK6X9WGVG2BB0WW2D7/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSWGAR4YQYF69KNR164W",
#       "attributes": {
#         "first_name": "Julie",
#         "last_name": "Rodriguez (Sample)",
#         "email": "julie.rodriguez@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSWGAR4YQYF69KNR164W/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSGWAV25R4F5614V6Q35",
#       "attributes": {
#         "first_name": "Stacey",
#         "last_name": "Johnson (Sample)",
#         "email": "stacey.johnson@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSGWAV25R4F5614V6Q35/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GSCTZCB0N1KHHKM0DEDT",
#       "attributes": {
#         "first_name": "Amanda",
#         "last_name": "Das (Sample)",
#         "email": "amanda.das@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GSCTZCB0N1KHHKM0DEDT/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GS4RR8XX4WBRG72XSGVM",
#       "attributes": {
#         "first_name": "Sarah",
#         "last_name": "Mason (Sample)",
#         "email": "sarah.mason@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GS8MG701Z9B47JS2TRFH",
#       "attributes": {
#         "first_name": "Lindsey",
#         "last_name": "Smith (Sample)",
#         "email": "lindsey.smith@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GS8MG701Z9B47JS2TRFH/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GRZV0M6R2SETYF8SASBF",
#       "attributes": {
#         "first_name": "Henry",
#         "last_name": "Downing (Sample)",
#         "email": "henry.downing@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GRZV0M6R2SETYF8SASBF/"
#       }
#     },
#     {
#       "type": "profile",
#       "id": "01JNT5GR3ZVQEW3QVTXKCRN4XD",
#       "attributes": {
#         "first_name": "John",
#         "last_name": "Chan (Sample)",
#         "email": "henry.chan@klaviyo-demo.com"
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT5GR3ZVQEW3QVTXKCRN4XD/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/events?fields%5Bevent%5D=timestamp,event_properties&fields%5Bmetric%5D=name,integration&fields%5Bprofile%5D=first_name,last_name,email&include=metric,profile",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    profile_for_event = klaviyo.Events.get_profile_for_event(
        id = "5ZePrxW9FC7", 
        additional_fields_profile = ['predictive_analytics'], 
        fields_profile = ['first_name', 'last_name', 'email']
    )
    show_json(profile_for_event)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": {
#     "type": "profile",
#     "id": "01JNT5GS4RR8XX4WBRG72XSGVM",
#     "attributes": {
#       "first_name": "Sarah",
#       "last_name": "Mason (Sample)",
#       "email": "sarah.mason@klaviyo-demo.com",
#       "predictive_analytics": {
#         "historic_number_of_orders": null,
#         "predicted_number_of_orders": null,
#         "average_days_between_orders": null,
#         "average_order_value": null,
#         "historic_clv": null,
#         "predicted_clv": null,
#         "total_clv": null,
#         "churn_probability": null,
#         "expected_date_of_next_order": null
#       }
#     },
#     "relationships": {
#       "lists": {
#         "links": {
#           "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/relationships/lists/",
#           "related": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/lists/"
#         }
#       },
#       "segments": {
#         "links": {
#           "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/relationships/segments/",
#           "related": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/segments/"
#         }
#       },
#       "conversation": {
#         "links": {
#           "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/relationships/conversation/",
#           "related": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/conversation/"
#         }
#       }
#     },
#     "links": {
#       "self": "https://a.klaviyo.com/api/profiles/01JNT5GS4RR8XX4WBRG72XSGVM/"
#     }
#   },
#   "links": {
#     "self": "https://a.klaviyo.com/api/events/5ZePrxW9FC7/profile?additional-fields%5Bprofile%5D=predictive_analytics&fields%5Bprofile%5D=first_name,last_name,email"
#   }
# }

# %% [markdown]
# ### Lists

# %%
try:
    lists = klaviyo.Lists.get_lists( 
        fields_list = ['name','updated'], 
        fields_tag = ['name'], 
        filter = None, 
        include = ['tags'], 
        page_cursor = None, 
        sort = None
    )
    show_json(lists)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "list",
#       "id": "Rh5Rfn",
#       "attributes": {
#         "name": "Preview List",
#         "updated": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "profiles": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/Rh5Rfn/relationships/profiles/",
#             "related": "https://a.klaviyo.com/api/lists/Rh5Rfn/profiles/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/Rh5Rfn/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/lists/Rh5Rfn/tags/"
#           }
#         },
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/Rh5Rfn/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/lists/Rh5Rfn/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/lists/Rh5Rfn/"
#       }
#     },
#     {
#       "type": "list",
#       "id": "TijKGM",
#       "attributes": {
#         "name": "Sample Data List",
#         "updated": "2025-03-08T06:01:44+00:00"
#       },
#       "relationships": {
#         "profiles": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/TijKGM/relationships/profiles/",
#             "related": "https://a.klaviyo.com/api/lists/TijKGM/profiles/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/TijKGM/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/lists/TijKGM/tags/"
#           }
#         },
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/TijKGM/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/lists/TijKGM/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/lists/TijKGM/"
#       }
#     },
#     {
#       "type": "list",
#       "id": "UWySBJ",
#       "attributes": {
#         "name": "SMS List",
#         "updated": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "profiles": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/UWySBJ/relationships/profiles/",
#             "related": "https://a.klaviyo.com/api/lists/UWySBJ/profiles/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/UWySBJ/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/lists/UWySBJ/tags/"
#           }
#         },
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/UWySBJ/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/lists/UWySBJ/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/lists/UWySBJ/"
#       }
#     },
#     {
#       "type": "list",
#       "id": "YxqDCG",
#       "attributes": {
#         "name": "Email List",
#         "updated": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "profiles": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/YxqDCG/relationships/profiles/",
#             "related": "https://a.klaviyo.com/api/lists/YxqDCG/profiles/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/YxqDCG/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/lists/YxqDCG/tags/"
#           }
#         },
#         "flow-triggers": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/lists/YxqDCG/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/lists/YxqDCG/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/lists/YxqDCG/"
#       }
#     }
#   ],
#   "included": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/lists?fields%5Blist%5D=name,updated&fields%5Btag%5D=name&include=tags",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    profiles_for_list = klaviyo.Lists.get_profiles_for_list(
        id = "YxqDCG", 
        additional_fields_profile = ['predictive_analytics'], 
        fields_profile = ['first_name', 'last_name', 'email'], 
        filter = None,
        page_cursor = None,
        page_size = None, 
        sort = None
    )

    show_json(profiles_for_list)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "profile",
#       "id": "01JNT4KAWQX1G11QYMR5Y17A5M",
#       "attributes": {
#         "first_name": null,
#         "last_name": null,
#         "email": "sherwin.varghese@neenopal.com",
#         "predictive_analytics": {
#           "historic_number_of_orders": null,
#           "predicted_number_of_orders": null,
#           "average_days_between_orders": null,
#           "average_order_value": null,
#           "historic_clv": null,
#           "predicted_clv": null,
#           "total_clv": null,
#           "churn_probability": null,
#           "expected_date_of_next_order": null
#         }
#       },
#       "relationships": {
#         "lists": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/relationships/lists/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/lists/"
#           }
#         },
#         "segments": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/relationships/segments/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/segments/"
#           }
#         },
#         "conversation": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/relationships/conversation/",
#             "related": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/conversation/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/profiles/01JNT4KAWQX1G11QYMR5Y17A5M/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/lists/YxqDCG/profiles?additional-fields%5Bprofile%5D=predictive_analytics&fields%5Bprofile%5D=first_name,last_name,email",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    tags_for_list =klaviyo.Lists.get_tags_for_list(
        id = "YxqDCG", 
        fields_tag = ['name']
    )
    show_json(tags_for_list)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/lists/YxqDCG/tags?fields%5Btag%5D=name"
#   }
# }

# %% [markdown]
# ### Coupons

# %%
try:
    coupons = klaviyo.Coupons.get_coupons(
        fields_coupon = ['description'], 
        page_cursor = None
    )
    show_json(coupons)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/coupons?fields%5Bcoupon%5D=description",
#     "next": null,
#     "prev": null
#   }
# }

# %% [markdown]
# ### Forms

# %%
try:
    forms = klaviyo.Forms.get_forms(
        fields_form = ['name', 'status'],
        filter = None,
        page_cursor = None, 
        page_size = None, 
        sort = None
    )
    show_json(forms)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "form",
#       "id": "XSeh2Y",
#       "attributes": {
#         "name": "Email Full Page",
#         "status": "live"
#       },
#       "relationships": {
#         "form-versions": {
#           "data": [
#             {
#               "type": "form-version",
#               "id": "18330001"
#             },
#             {
#               "type": "form-version",
#               "id": "18329990"
#             }
#           ],
#           "links": {
#             "self": "https://a.klaviyo.com/api/forms/XSeh2Y/relationships/form-versions/",
#             "related": "https://a.klaviyo.com/api/forms/XSeh2Y/form-versions/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/forms/XSeh2Y/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/forms?fields%5Bform%5D=name,status",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    versions_of_forms = klaviyo.Forms.get_versions_for_form(
        id = "XSeh2Y", 
        fields_form_version = ['form_type','ab_test'],
        filter = None, 
        page_cursor = None, 
        page_size = None, 
        sort = None
    )
    show_json(versions_of_forms)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "form-version",
#       "id": "18329990",
#       "attributes": {
#         "form_type": "full_page",
#         "ab_test": null
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/form-versions/18329990/"
#       }
#     },
#     {
#       "type": "form-version",
#       "id": "18330001",
#       "attributes": {
#         "form_type": "full_page",
#         "ab_test": null
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/form-versions/18330001/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/forms/XSeh2Y/form-versions?fields%5Bform-version%5D=form_type,ab_test"
#   }
# }

# %% [markdown]
# ### Flows

# %%
try:
    flows = klaviyo.Flows.get_flows(
        fields_flow_action = ['action_type', 'status'], 
        fields_flow = ['name','archived'], 
        fields_tag = ['name'], 
        filter = None, 
        include = ['tags', 'flow-actions'], 
        page_cursor = None, 
        page_size = None, 
        sort = None
    )
    show_json(flows)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "flow",
#       "id": "SDXTaS",
#       "attributes": {
#         "name": "Email Welcome Series Customer vs Non-Customer",
#         "archived": false
#       },
#       "relationships": {
#         "flow-actions": {
#           "data": [
#             {
#               "type": "flow-action",
#               "id": "77959894"
#             },
#             {
#               "type": "flow-action",
#               "id": "77959895"
#             },
#             {
#               "type": "flow-action",
#               "id": "77959898"
#             },
#             {
#               "type": "flow-action",
#               "id": "77959893"
#             },
#             {
#               "type": "flow-action",
#               "id": "77959897"
#             },
#             {
#               "type": "flow-action",
#               "id": "77959896"
#             }
#           ],
#           "links": {
#             "self": "https://a.klaviyo.com/api/flows/SDXTaS/relationships/flow-actions/",
#             "related": "https://a.klaviyo.com/api/flows/SDXTaS/flow-actions/"
#           }
#         },
#         "tags": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/flows/SDXTaS/relationships/tags/",
#             "related": "https://a.klaviyo.com/api/flows/SDXTaS/tags/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/flows/SDXTaS/"
#       }
#     }
#   ],
#   "included": [
#     {
#       "type": "flow-action",
#       "id": "77959894",
#       "attributes": {
#         "action_type": "SEND_EMAIL",
#         "status": "live"
#       },
#       "relationships": {
#         "flow": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959894/relationships/flow/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959894/flow/"
#           }
#         },
#         "flow-messages": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959894/relationships/flow-messages/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959894/flow-messages/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/flow-actions/77959894/"
#       }
#     },
#     {
#       "type": "flow-action",
#       "id": "77959895",
#       "attributes": {
#         "action_type": "SEND_EMAIL",
#         "status": "live"
#       },
#       "relationships": {
#         "flow": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959895/relationships/flow/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959895/flow/"
#           }
#         },
#         "flow-messages": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959895/relationships/flow-messages/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959895/flow-messages/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/flow-actions/77959895/"
#       }
#     },
#     {
#       "type": "flow-action",
#       "id": "77959898",
#       "attributes": {
#         "action_type": "SEND_EMAIL",
#         "status": "live"
#       },
#       "relationships": {
#         "flow": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959898/relationships/flow/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959898/flow/"
#           }
#         },
#         "flow-messages": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959898/relationships/flow-messages/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959898/flow-messages/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/flow-actions/77959898/"
#       }
#     },
#     {
#       "type": "flow-action",
#       "id": "77959893",
#       "attributes": {
#         "action_type": "BOOLEAN_BRANCH",
#         "status": "live"
#       },
#       "relationships": {
#         "flow": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959893/relationships/flow/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959893/flow/"
#           }
#         },
#         "flow-messages": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959893/relationships/flow-messages/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959893/flow-messages/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/flow-actions/77959893/"
#       }
#     },
#     {
#       "type": "flow-action",
#       "id": "77959897",
#       "attributes": {
#         "action_type": "BOOLEAN_BRANCH",
#         "status": "live"
#       },
#       "relationships": {
#         "flow": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959897/relationships/flow/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959897/flow/"
#           }
#         },
#         "flow-messages": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959897/relationships/flow-messages/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959897/flow-messages/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/flow-actions/77959897/"
#       }
#     },
#     {
#       "type": "flow-action",
#       "id": "77959896",
#       "attributes": {
#         "action_type": "TIME_DELAY",
#         "status": "live"
#       },
#       "relationships": {
#         "flow": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959896/relationships/flow/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959896/flow/"
#           }
#         },
#         "flow-messages": {
#           "links": {
#             "self": "https://a.klaviyo.com/api/flow-actions/77959896/relationships/flow-messages/",
#             "related": "https://a.klaviyo.com/api/flow-actions/77959896/flow-messages/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/flow-actions/77959896/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/flows?fields%5Bflow-action%5D=action_type,status&fields%5Bflow%5D=name,archived&fields%5Btag%5D=name&include=tags,flow-actions",
#     "next": null,
#     "prev": null
#   }
# }

# %% [markdown]
# ### Metrics

# %%
try:
    metrics = klaviyo.Metrics.get_metrics(
        fields_metric = ['name','created'], 
        filter = None, 
        include = ['flow-triggers'], 
        page_cursor = None
    )
    show_json(metrics)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "metric",
#       "id": "QTWzEV",
#       "attributes": {
#         "name": "Opened Email",
#         "created": "2025-03-08T05:45:38+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/QTWzEV/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/QTWzEV/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/QTWzEV/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "RU6TRZ",
#       "attributes": {
#         "name": "Sent SMS",
#         "created": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/RU6TRZ/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/RU6TRZ/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/RU6TRZ/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "RrgBQU",
#       "attributes": {
#         "name": "Refunded Order",
#         "created": "2025-03-08T06:01:49+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/RrgBQU/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/RrgBQU/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/RrgBQU/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "S4hEtx",
#       "attributes": {
#         "name": "Started Checkout",
#         "created": "2025-03-08T06:01:48+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/S4hEtx/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/S4hEtx/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/S4hEtx/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "S5mqyM",
#       "attributes": {
#         "name": "Dropped Email",
#         "created": "2025-03-08T05:45:38+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/S5mqyM/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/S5mqyM/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/S5mqyM/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "SGntbq",
#       "attributes": {
#         "name": "Clicked Email",
#         "created": "2025-03-08T05:45:38+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/SGntbq/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/SGntbq/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/SGntbq/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "Sx7WuC",
#       "attributes": {
#         "name": "Clicked SMS",
#         "created": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/Sx7WuC/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/Sx7WuC/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/Sx7WuC/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "TGwMnu",
#       "attributes": {
#         "name": "Received Automated Response SMS",
#         "created": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/TGwMnu/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/TGwMnu/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/TGwMnu/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "TQHxY2",
#       "attributes": {
#         "name": "Ordered Product",
#         "created": "2025-03-08T06:01:48+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/TQHxY2/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/TQHxY2/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/TQHxY2/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "UjxPZ7",
#       "attributes": {
#         "name": "Failed to Deliver SMS",
#         "created": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/UjxPZ7/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/UjxPZ7/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/UjxPZ7/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "UtJAAD",
#       "attributes": {
#         "name": "Viewed Product",
#         "created": "2025-03-08T06:01:47+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/UtJAAD/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/UtJAAD/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/UtJAAD/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "UuNkFT",
#       "attributes": {
#         "name": "Clicked email to unsubscribe",
#         "created": "2025-03-08T05:45:38+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/UuNkFT/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/UuNkFT/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/UuNkFT/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "V28nRS",
#       "attributes": {
#         "name": "Cancelled Order",
#         "created": "2025-03-08T06:01:49+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/V28nRS/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/V28nRS/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/V28nRS/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "V7Ppiw",
#       "attributes": {
#         "name": "Active on Site",
#         "created": "2025-03-08T05:45:38+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/V7Ppiw/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/V7Ppiw/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/V7Ppiw/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "VD9ruv",
#       "attributes": {
#         "name": "Placed Order",
#         "created": "2025-03-08T06:01:48+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/VD9ruv/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/VD9ruv/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/VD9ruv/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "VuWESX",
#       "attributes": {
#         "name": "Failed to Deliver Automated Response SMS",
#         "created": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/VuWESX/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/VuWESX/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/VuWESX/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "W7XHvA",
#       "attributes": {
#         "name": "Unsubscribed from SMS Marketing",
#         "created": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/W7XHvA/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/W7XHvA/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/W7XHvA/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "WJYL8d",
#       "attributes": {
#         "name": "Received SMS",
#         "created": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/WJYL8d/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/WJYL8d/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/WJYL8d/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "WUfgNZ",
#       "attributes": {
#         "name": "Received Email",
#         "created": "2025-03-08T05:45:38+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/WUfgNZ/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/WUfgNZ/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/WUfgNZ/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "Wheecn",
#       "attributes": {
#         "name": "Marked Email as Spam",
#         "created": "2025-03-08T05:45:38+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/Wheecn/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/Wheecn/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/Wheecn/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "XUpB25",
#       "attributes": {
#         "name": "Subscribed to SMS Marketing",
#         "created": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/XUpB25/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/XUpB25/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/XUpB25/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "Xhnyps",
#       "attributes": {
#         "name": "Relayed SMS",
#         "created": "2025-03-08T05:45:40+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/Xhnyps/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/Xhnyps/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/Xhnyps/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "XrziYY",
#       "attributes": {
#         "name": "Fulfilled Order",
#         "created": "2025-03-08T06:01:48+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/XrziYY/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/XrziYY/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/XrziYY/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "Y4AmBB",
#       "attributes": {
#         "name": "Added to Cart",
#         "created": "2025-03-08T06:01:48+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/Y4AmBB/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/Y4AmBB/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/Y4AmBB/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "Y5E7GR",
#       "attributes": {
#         "name": "Bounced Email",
#         "created": "2025-03-08T05:45:38+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/Y5E7GR/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/Y5E7GR/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/Y5E7GR/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "QSnvJc",
#       "attributes": {
#         "name": "Submitted Form",
#         "created": "2025-03-13T08:15:12+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/QSnvJc/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/QSnvJc/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/QSnvJc/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "SENpeF",
#       "attributes": {
#         "name": "submitted_form_step",
#         "created": "2025-03-13T08:15:12+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/SENpeF/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/SENpeF/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/SENpeF/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "ThPrRi",
#       "attributes": {
#         "name": "qualified_form",
#         "created": "2025-03-13T08:15:12+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/ThPrRi/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/ThPrRi/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/ThPrRi/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "UtegKa",
#       "attributes": {
#         "name": "viewed_form_step",
#         "created": "2025-03-13T08:15:12+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/UtegKa/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/UtegKa/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/UtegKa/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "V6fjmM",
#       "attributes": {
#         "name": "Viewed Form",
#         "created": "2025-03-13T08:15:12+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/V6fjmM/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/V6fjmM/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/V6fjmM/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "WSFcSg",
#       "attributes": {
#         "name": "Closed Form",
#         "created": "2025-03-13T08:15:12+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/WSFcSg/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/WSFcSg/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/WSFcSg/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "WfEafD",
#       "attributes": {
#         "name": "Form completed by profile",
#         "created": "2025-03-13T08:15:12+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/WfEafD/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/WfEafD/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/WfEafD/"
#       }
#     },
#     {
#       "type": "metric",
#       "id": "Y463L8",
#       "attributes": {
#         "name": "Form submitted by profile",
#         "created": "2025-03-13T08:15:12+00:00"
#       },
#       "relationships": {
#         "flow-triggers": {
#           "data": [],
#           "links": {
#             "self": "https://a.klaviyo.com/api/metrics/Y463L8/relationships/flow-triggers/",
#             "related": "https://a.klaviyo.com/api/metrics/Y463L8/flow-triggers/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metrics/Y463L8/"
#       }
#     }
#   ],
#   "included": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/metrics?fields%5Bmetric%5D=name,created&include=flow-triggers",
#     "next": null,
#     "prev": null
#   }
# }

# %%
try:
    properties_of_metric = klaviyo.Metrics.get_properties_for_metric(
        id = "QTWzEV" , 
        additional_fields_metric_property = ['sample_values'], 
        fields_metric_property = ['property','label']
    )
    show_json(properties_of_metric)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [
#     {
#       "type": "metric-property",
#       "id": "UVRXekVWLiRtZXNzYWdl",
#       "attributes": {
#         "property": "$message",
#         "label": "Message",
#         "sample_values": null
#       },
#       "relationships": {
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "QTWzEV"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLiRtZXNzYWdl/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLiRtZXNzYWdl/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLiRtZXNzYWdl/"
#       }
#     },
#     {
#       "type": "metric-property",
#       "id": "UVRXekVWLkNhbXBhaWduIE5hbWU",
#       "attributes": {
#         "property": "Campaign Name",
#         "label": "Campaign Name",
#         "sample_values": null
#       },
#       "relationships": {
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "QTWzEV"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNhbXBhaWduIE5hbWU/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNhbXBhaWduIE5hbWU/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNhbXBhaWduIE5hbWU/"
#       }
#     },
#     {
#       "type": "metric-property",
#       "id": "UVRXekVWLkNsaWVudCBOYW1l",
#       "attributes": {
#         "property": "Client Name",
#         "label": "Client Name",
#         "sample_values": null
#       },
#       "relationships": {
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "QTWzEV"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBOYW1l/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBOYW1l/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBOYW1l/"
#       }
#     },
#     {
#       "type": "metric-property",
#       "id": "UVRXekVWLkNsaWVudCBPUw",
#       "attributes": {
#         "property": "Client OS",
#         "label": "Client OS",
#         "sample_values": null
#       },
#       "relationships": {
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "QTWzEV"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBPUw/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBPUw/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBPUw/"
#       }
#     },
#     {
#       "type": "metric-property",
#       "id": "UVRXekVWLkNsaWVudCBPUyBGYW1pbHk",
#       "attributes": {
#         "property": "Client OS Family",
#         "label": "Client OS Family",
#         "sample_values": null
#       },
#       "relationships": {
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "QTWzEV"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBPUyBGYW1pbHk/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBPUyBGYW1pbHk/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBPUyBGYW1pbHk/"
#       }
#     },
#     {
#       "type": "metric-property",
#       "id": "UVRXekVWLkNsaWVudCBUeXBl",
#       "attributes": {
#         "property": "Client Type",
#         "label": "Client Type",
#         "sample_values": null
#       },
#       "relationships": {
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "QTWzEV"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBUeXBl/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBUeXBl/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLkNsaWVudCBUeXBl/"
#       }
#     },
#     {
#       "type": "metric-property",
#       "id": "UVRXekVWLm1hY2hpbmVfb3Blbg",
#       "attributes": {
#         "property": "machine_open",
#         "label": "Apple Privacy Open",
#         "sample_values": null
#       },
#       "relationships": {
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "QTWzEV"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLm1hY2hpbmVfb3Blbg/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLm1hY2hpbmVfb3Blbg/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLm1hY2hpbmVfb3Blbg/"
#       }
#     },
#     {
#       "type": "metric-property",
#       "id": "UVRXekVWLlN1YmplY3Q",
#       "attributes": {
#         "property": "Subject",
#         "label": "Subject",
#         "sample_values": null
#       },
#       "relationships": {
#         "metric": {
#           "data": {
#             "type": "metric",
#             "id": "QTWzEV"
#           },
#           "links": {
#             "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLlN1YmplY3Q/relationships/metric/",
#             "related": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLlN1YmplY3Q/metric/"
#           }
#         }
#       },
#       "links": {
#         "self": "https://a.klaviyo.com/api/metric-properties/UVRXekVWLlN1YmplY3Q/"
#       }
#     }
#   ],
#   "links": {
#     "self": "https://a.klaviyo.com/api/metrics/QTWzEV/metric-properties?additional-fields%5Bmetric-property%5D=sample_values&fields%5Bmetric-property%5D=property,label"
#   }
# }

# %%
try:
    flows_for_metric = klaviyo.Metrics.get_flows_triggered_by_metric(
        id = "Y463L8",
        fields_flow = ['name']
    )
    show_json(flows_for_metric)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/metrics/Y463L8/flow-triggers?fields%5Bflow%5D=name"
#   }
# }

# %% [markdown]
# ### Images

# %%
try:
    images = klaviyo.Images.get_images(
        fields_image = ['name'], 
        filter = None,
        page_cursor = None, 
        page_size = None, 
        sort = None
    )
    show_json(images)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {
#   "data": [],
#   "links": {
#     "self": "https://a.klaviyo.com/api/images?fields%5Bimage%5D=name",
#     "next": null,
#     "prev": null
#   }
# }
