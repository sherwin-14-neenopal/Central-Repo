# %%
import os
import json
import dwollav2
import pandas as pd


from typing import Optional
from typing import Dict, Any
from dotenv import load_dotenv

# %%
load_dotenv(os.path.join("..", "..", "config", ".env"))

client = dwollav2.Client(
  key = os.environ['DWOLLA_KEY'],
  secret = os.environ['DWOLLA_SECRET'],
  environment = 'sandbox'
)

token = client.Token(access_token = os.environ['ACCESS_TOKEN_DWOLLA'],expires_in = 3600)

# %%
def show_json(variable: Dict[str, Any]) -> None:
    print(json.dumps(variable, indent = 2))

# %% [markdown]
# ### Customers

# %%
try:
    customers = token.get('https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8')
    show_json(customers.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %%
try:
    business_classifications = token.get('https://api.dwolla.com/business-classifications')
    show_json(business_classifications.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %%
try:
    customers_all = token.get('https://api-sandbox.dwolla.com/customers')
    show_json(customers_all.body)

except Exception as e:
    print(f'An error occurred: {e}')
# Out:
# {
#   "_links": {
#     "self": {
#       "href": "https://api-sandbox.dwolla.com/customers",
#       "type": "application/vnd.dwolla.v1.hal+json",
#       "resource-type": "customer"
#     },
#     "first": {
#       "href": "https://api-sandbox.dwolla.com/customers?limit=25&offset=0",
#       "type": "application/vnd.dwolla.v1.hal+json",
#       "resource-type": "customer"
#     },
#     "last": {
#       "href": "https://api-sandbox.dwolla.com/customers?limit=25&offset=0",
#       "type": "application/vnd.dwolla.v1.hal+json",
#       "resource-type": "customer"
#     }
#   },
#   "_embedded": {
#     "customers": [
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "receive": {
#             "href": "https://api-sandbox.dwolla.com/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "395aaa1c-d7d0-4b1c-a425-8497f03039a8",
#         "firstName": "Laura ",
#         "lastName": "Thomas",
#         "email": "bookings@adventuretravel.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:17:47.843Z",
#         "businessName": "Adventure Travel Agency"
#       },
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/96a84af5-1ea4-495d-99cf-9608dd3bff45",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/96a84af5-1ea4-495d-99cf-9608dd3bff45",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/96a84af5-1ea4-495d-99cf-9608dd3bff45",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/96a84af5-1ea4-495d-99cf-9608dd3bff45",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/96a84af5-1ea4-495d-99cf-9608dd3bff45/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/96a84af5-1ea4-495d-99cf-9608dd3bff45/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "96a84af5-1ea4-495d-99cf-9608dd3bff45",
#         "firstName": "David ",
#         "lastName": "Anderson",
#         "email": "support@urbanfashion.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:17:02.097Z",
#         "businessName": "Urban Fashion Boutique"
#       },
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/b151f160-1a97-4330-ba98-de56efec552a",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/b151f160-1a97-4330-ba98-de56efec552a",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/b151f160-1a97-4330-ba98-de56efec552a",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/b151f160-1a97-4330-ba98-de56efec552a",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/b151f160-1a97-4330-ba98-de56efec552a/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/b151f160-1a97-4330-ba98-de56efec552a/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "b151f160-1a97-4330-ba98-de56efec552a",
#         "firstName": "Sarah ",
#         "lastName": "Miller",
#         "email": "info@brightfutureedu.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:16:15.460Z",
#         "businessName": "Bright Future Education"
#       },
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/63e733a6-5772-41ae-a8a6-7a83e8020f90",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/63e733a6-5772-41ae-a8a6-7a83e8020f90",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/63e733a6-5772-41ae-a8a6-7a83e8020f90",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/63e733a6-5772-41ae-a8a6-7a83e8020f90",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/63e733a6-5772-41ae-a8a6-7a83e8020f90/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/63e733a6-5772-41ae-a8a6-7a83e8020f90/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "63e733a6-5772-41ae-a8a6-7a83e8020f90",
#         "firstName": "Michael ",
#         "lastName": "Taylor",
#         "email": "contact@healthandwellness.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:15:17.210Z",
#         "businessName": "Health &amp; Wellness Inc."
#       },
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/71027bfe-1866-4532-a3c4-b3035a1e2b9a",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/71027bfe-1866-4532-a3c4-b3035a1e2b9a",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/71027bfe-1866-4532-a3c4-b3035a1e2b9a",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/71027bfe-1866-4532-a3c4-b3035a1e2b9a",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/71027bfe-1866-4532-a3c4-b3035a1e2b9a/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/71027bfe-1866-4532-a3c4-b3035a1e2b9a/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "71027bfe-1866-4532-a3c4-b3035a1e2b9a",
#         "firstName": "Emily ",
#         "lastName": "Wilson",
#         "email": "sales@globaltradeco.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:14:25.010Z",
#         "businessName": " Global Trade Co."
#       },
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/b8d875a0-80b1-4d0a-bb79-5bf0f22abe18",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/b8d875a0-80b1-4d0a-bb79-5bf0f22abe18",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/b8d875a0-80b1-4d0a-bb79-5bf0f22abe18",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/b8d875a0-80b1-4d0a-bb79-5bf0f22abe18",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/b8d875a0-80b1-4d0a-bb79-5bf0f22abe18/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/b8d875a0-80b1-4d0a-bb79-5bf0f22abe18/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "b8d875a0-80b1-4d0a-bb79-5bf0f22abe18",
#         "firstName": "Charlie ",
#         "lastName": "Davis",
#         "email": "inquiries@creativedesigns.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:09:10.757Z",
#         "businessName": "Creative Designs Studio"
#       },
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/e8bd6d98-891a-475b-9d65-71cc2cad4225",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/e8bd6d98-891a-475b-9d65-71cc2cad4225",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/e8bd6d98-891a-475b-9d65-71cc2cad4225",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/e8bd6d98-891a-475b-9d65-71cc2cad4225",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/e8bd6d98-891a-475b-9d65-71cc2cad4225/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/e8bd6d98-891a-475b-9d65-71cc2cad4225/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "e8bd6d98-891a-475b-9d65-71cc2cad4225",
#         "firstName": "Bob",
#         "lastName": " Brown",
#         "email": "hello@techinnovations.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:08:44.280Z",
#         "businessName": " Tech Innovations LLC"
#       },
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/70213755-4e65-4cc1-9493-b6702994ed9a",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/70213755-4e65-4cc1-9493-b6702994ed9a",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/70213755-4e65-4cc1-9493-b6702994ed9a",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/70213755-4e65-4cc1-9493-b6702994ed9a",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/70213755-4e65-4cc1-9493-b6702994ed9a/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/70213755-4e65-4cc1-9493-b6702994ed9a/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "70213755-4e65-4cc1-9493-b6702994ed9a",
#         "firstName": "Alice",
#         "lastName": " Johnson",
#         "email": "support@greenthumbgardening.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:08:11.200Z",
#         "businessName": "Green Thumb Gardening"
#       },
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/1e2bb9cb-7d19-443c-ace5-8991cd8514ab",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/1e2bb9cb-7d19-443c-ace5-8991cd8514ab",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/1e2bb9cb-7d19-443c-ace5-8991cd8514ab",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/1e2bb9cb-7d19-443c-ace5-8991cd8514ab",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/1e2bb9cb-7d19-443c-ace5-8991cd8514ab/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/1e2bb9cb-7d19-443c-ace5-8991cd8514ab/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "1e2bb9cb-7d19-443c-ace5-8991cd8514ab",
#         "firstName": "Jane ",
#         "lastName": "Smith",
#         "email": "info@stellarsolutions.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:07:40.793Z",
#         "businessName": "Stellar Solutions"
#       },
#       {
#         "_links": {
#           "deactivate": {
#             "href": "https://api-sandbox.dwolla.com/customers/1a54c9e8-100a-4989-9313-a68c5ab4b343",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "self": {
#             "href": "https://api-sandbox.dwolla.com/customers/1a54c9e8-100a-4989-9313-a68c5ab4b343",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "edit-form": {
#             "href": "https://api-sandbox.dwolla.com/customers/1a54c9e8-100a-4989-9313-a68c5ab4b343",
#             "type": "application/vnd.dwolla.v1.hal+json; profile=\"https://github.com/dwolla/hal-forms\"",
#             "resource-type": "customer"
#           },
#           "edit": {
#             "href": "https://api-sandbox.dwolla.com/customers/1a54c9e8-100a-4989-9313-a68c5ab4b343",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "customer"
#           },
#           "funding-sources": {
#             "href": "https://api-sandbox.dwolla.com/customers/1a54c9e8-100a-4989-9313-a68c5ab4b343/funding-sources",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "funding-source"
#           },
#           "transfers": {
#             "href": "https://api-sandbox.dwolla.com/customers/1a54c9e8-100a-4989-9313-a68c5ab4b343/transfers",
#             "type": "application/vnd.dwolla.v1.hal+json",
#             "resource-type": "transfer"
#           }
#         },
#         "id": "1a54c9e8-100a-4989-9313-a68c5ab4b343",
#         "firstName": "John",
#         "lastName": "Doe",
#         "email": "contact@acmecorp.com",
#         "type": "receive-only",
#         "status": "unverified",
#         "created": "2025-03-18T08:06:54.333Z",
#         "businessName": "Acme Corp"
#       }
#     ]
#   },
#   "total": 10
# }

# %% [markdown]
# ### Benefical Owners

# %%
try:
    benefical_owners = token.get(f' https://api.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/beneficial-owners')
    show_json(benefical_owners.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Funding Sources

# %%
try:
    funding_sources_customer = token.get(f'https://api.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/funding-sources')
    show_json(funding_sources_customer.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Transfers

# %%
try:
    transfers = token.get(f'https://api.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/transfers?startAmount=100.00')
    show_json(transfers.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %%
try:
    fees_charged = token.get(f'https://api.dwolla.com/transfers/279ada0b-3909-f011-acd5-02ab38c54207/fees')
    show_json(fees_charged.body)

except Exception as e:
    print(f'An error occurred: {e}')
# Out:
# {
#   "_links": {
#     "self": {
#       "href": "https://api-sandbox.dwolla.com/transfers/279ada0b-3909-f011-acd5-02ab38c54207/fees",
#       "type": "application/vnd.dwolla.v1.hal+json",
#       "resource-type": "fee"
#     }
#   },
#   "_embedded": {
#     "fees": []
#   },
#   "transactions": [],
#   "total": 0
# }
