# %% [markdown]
# ## Dwolla API Integration Examples

# %%
import os
import json
import dwollav2
import pandas as pd


from typing import Optional
from typing import Dict, Any
from dotenv import load_dotenv

# %% [markdown]
# ### Connection to Dwolla API
#
# You need to ensure that you have your `ACCESS_TOKEN` from dwolla developer portal. If you don't have that yet, you can follow the `dwolla.md` document in the `docs` dir to generate an token for your usecase.

# %%
load_dotenv(os.path.join("..", "..", "config", ".env"))

client = dwollav2.Client(
  key = os.environ['DWOLLA_KEY'],
  secret = os.environ['DWOLLA_SECRET'],
  environment = 'sandbox'
)

token = client.Token(access_token = os.environ['ACCESS_TOKEN_DWOLLA'],expires_in = 3600)

# %%
def show_json(variable: Dict[str, Any]) -> None:
    print(json.dumps(variable, indent = 2))

# %% [markdown]
# ### Customers

# %%
try:
    customers = token.get('https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8')
    show_json(customers.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %%
try:
    business_classifications = token.get('https://api-sandbox.dwolla.com/business-classifications')
    show_json(business_classifications.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %%
try:
    customers_all = token.get('https://api-sandbox.dwolla.com/customers')
    show_json(customers_all.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Benefical Owners

# %%
try:
    benefical_owners = token.get(f'https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/beneficial-owners')
    show_json(benefical_owners.body)
except Exception as e:
    print(f'An error occurred: {e}')

# %%
try:
    documents = token.get(f'https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/documents')
    show_json(documents.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Open Banking

# %%
try:
    exchange_connections = token.get(f'https://api.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/available-exchange-connections')
    show_json(exchange_connections.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %%
try:
    exchange_connections = token.get(f'https://api.dwolla.com/funding-source/9a998e61-32a5-4448-9d52-f7d6049328a5/balance')
    show_json(exchange_connections.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Funding Sources

# %%
try:
    funding_sources_customer = token.get(f'https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/funding-sources')
    show_json(funding_sources_customer.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Transfers

# %%
try:
    transfers = token.get(f'https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/transfers?startAmount=100.00')
    show_json(transfers.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %%
try:
    fees_charged = token.get(f'https://api-sandbox.dwolla.com/transfers/279ada0b-3909-f011-acd5-02ab38c54207/fees')
    show_json(fees_charged.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Labels

# %%
try:
    labels = token.get(f'https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/labels')
    show_json(labels.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Mass Payments

# %%
try:
    mass_payments = token.get(f' https://api-sandbox.dwolla.com/customers/395aaa1c-d7d0-4b1c-a425-8497f03039a8/mass-payments')
    show_json(mass_payments.body)

except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Events

# %%
try:
    events = token.get(f'https://api-sandbox.dwolla.com/events?limit=10')
    show_json(events.body)

except Exception as e:
    print(f'An error occurred: {e}')
