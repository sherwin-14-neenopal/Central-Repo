# %%
import os
import google.oauth2.credentials
import google_auth_oauthlib.flow

from typing import Any, Dict
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
SCOPES = ['https://www.googleapis.com/auth/yt-analytics.readonly']

API_SERVICE_NAME = 'youtubeAnalytics'
API_VERSION = 'v2'
CLIENT_SECRETS_FILE = '../../config/client_secrets_youtube.json'

# %%
def get_service():
  flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
  credentials = flow.run_local_server(port=0)
  return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

def execute_api_request(client_library_function, **kwargs):
  response = client_library_function(**kwargs).execute()
  return response

# %%
ya = get_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=986600960035-adoribjb9aue521l8tu4ugdb34jg3jet.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A59641%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyt-analytics.readonly&state=UdPwkVydIXtAq9RH1kyfekX4uVtLWz&access_type=offline

# %% [markdown]
# ### Reports

# %%
result = execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics='estimatedMinutesWatched,views,likes,subscribersGained',
      dimensions='day',
      sort='day'
)

# %%
operating_system_report = execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics='estimatedMinutesWatched,views',
      dimensions='operatingSystem'
)

# %%
device_type_report = execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics='estimatedMinutesWatched,views',
      dimensions='deviceType'
)

# %%
demographics_report = execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics='viewerPercentage',
      dimensions='ageGroup'
)

# %%
time_based_report = execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics='averageViewDuration',
      dimensions='day'
)

# %%
video_playback_locations_report = execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics= 'estimatedMinutesWatched,views',
      dimensions='insightPlaybackLocationType'
)

# %%
traffic_sources_report =  execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics= 'estimatedMinutesWatched,views',
      dimensions='insightTrafficSourceType'
)

# %%
ad_performance_reports =  execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics= 'grossRevenue',
      dimensions='day'
)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ad_performance_reports =  execute_api_request(ya.reports().query,
#       2       ids='channel==mine',
#       3       startDate='2025-03-31',
#       4       endDate='2025-03-31',
#       5       metrics= 'grossRevenue',
#       6       dimensions='day'
#       7 )
#
# Cell In[3], line 7, in execute_api_request(client_library_function, **kwargs)
#       6 def execute_api_request(client_library_function, **kwargs):
# ----> 7   response = client_library_function(**kwargs).execute()
#       8   return response
#
# File c:\Users\SherwinVarghese\AppData\Local\pypoetry\Cache\virtualenvs\central-repo-C1khgJZ_-py3.13\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\SherwinVarghese\AppData\Local\pypoetry\Cache\virtualenvs\central-repo-C1khgJZ_-py3.13\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 401 when requesting https://youtubeanalytics.googleapis.com/v2/reports?ids=channel%3D%3Dmine&startDate=2025-03-31&endDate=2025-03-31&metrics=grossRevenue&dimensions=day&alt=json returned "Insufficient permission to access this report.". Details: "[{'message': 'Insufficient permission to access this report.', 'domain': 'global', 'reason': 'unauthorized'}]">

# %%
membership_reports =  execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics= 'membershipsCancellationSurveyResponses',
      dimensions='membershipsCancellationSurveyReason'
)

# %%
audience_retention_report  =  execute_api_request(ya.reports().query,
      ids='channel==mine',
      startDate='2025-03-31',
      endDate='2025-03-31',
      metrics= 'audienceWatchRatio',
      dimensions='elapsedVideoTimeRatio'
)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 audience_retention_report  =  execute_api_request(ya.reports().query,
#       2       ids='channel==mine',
#       3       startDate='2025-03-31',
#       4       endDate='2025-03-31',
#       5       metrics= 'audienceWatchRatio',
#       6       dimensions='elapsedVideoTimeRatio'
#       7 )
#
# Cell In[3], line 7, in execute_api_request(client_library_function, **kwargs)
#       6 def execute_api_request(client_library_function, **kwargs):
# ----> 7   response = client_library_function(**kwargs).execute()
#       8   return response
#
# File c:\Users\SherwinVarghese\AppData\Local\pypoetry\Cache\virtualenvs\central-repo-C1khgJZ_-py3.13\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\SherwinVarghese\AppData\Local\pypoetry\Cache\virtualenvs\central-repo-C1khgJZ_-py3.13\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://youtubeanalytics.googleapis.com/v2/reports?ids=channel%3D%3Dmine&startDate=2025-03-31&endDate=2025-03-31&metrics=audienceWatchRatio&dimensions=elapsedVideoTimeRatio&alt=json returned "The query is not supported. Check the documentation at https://developers.google.com/youtube/analytics/v2/available_reports for a list of supported queries.". Details: "[{'message': 'The query is not supported. Check the documentation at https://developers.google.com/youtube/analytics/v2/available_reports for a list of supported queries.', 'domain': 'global', 'reason': 'badRequest'}]">
